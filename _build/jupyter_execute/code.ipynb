# %% [markdown]
# # Finding nonlinear solutions

# %%
import numpy as np
from scipy.optimize import fsolve

def pack(Etam,Bj,Ub,Q,R): # bind into one vector A
    N=len(Bj)
    A=np.zeros(2*N+4)
    A[:N+1]=Etam
    A[N+1:2*N+1]=Bj
    A[2*N+1:]=Ub,Q,R
    return A

def unpack(A):
    N=len(A)//2-2
    return A[:N+1],A[N+1:2*N+1],*A[2*N+1:] # split A into Etam,Bj,Ub,Q,R

# %%
def nwfourier(N,H,d=0): # defaults to d=0 representing deep water
    
    def F(A): # set of conditions on boundaries
        Etam,Bj,Ub,Q,R=unpack(A)
        Etamj=Etam.reshape((N+1,1))@j.reshape((1,N))
        CEmj,SEmj=C(Etamj),S(Etamj)
        kin=-Ub*Etam+((SEmj*CXmj))@(Bj/Chjd)+Q
        Um=-Ub+((CEmj*CXmj))@(j*Bj/Chjd)
        Vm=((SEmj*SXmj))@(j*Bj/Chjd)
        dyn=(Um**2+Vm**2)/2+Etam-R
        height=Etam[0]-Etam[-1]
        depth=((Etam[0]+Etam[-1])/2+sum(Etam[1:-1]))/N
        return np.hstack([kin,dyn,height-H,depth-d])

    Bj0=np.zeros(N)
    Ub0=1 if d==0 else np.tanh(d)**(1/2)
    Bj0[0]=H/2/Ub0
    Q0,R0=Ub0*d,Ub0**2/2+d
    Xm=np.linspace(0,np.pi,N+1)
    Etam0=d+H*np.cos(Xm)/2
    
    A0=pack(Etam0,Bj0,Ub0,Q0,R0)

    j=np.arange(1,N+1)
    Xmj=Xm.reshape((N+1,1))@j.reshape((1,N))
    CXmj,SXmj,Chjd=np.cos(Xmj),np.sin(Xmj),np.cosh(j*d)
    C,S=(np.exp,np.exp) if d==0 else (np.cosh,np.sinh)
    return unpack(fsolve(F,A0,xtol=1e-13))

# %%
import matplotlib.pyplot as plt
for j in range(1):
    NV=np.array([(N,nwfourier(N,0.1945,0.6484)[1][j]) for N in range(12,20)])    
    plt.plot(NV.T[0],NV.T[1],label=f'j={j+1}')
plt.legend()

# %%
for j in range(5):
    print(nwfourier(16,0.1945)[1][j])
    NV=np.array([(d,nwfourier(16,0.1945,d)[1][j]) for d in np.linspace(1,10)])
    plt.plot(NV.T[0],NV.T[1],label=f'j={j+1}')
plt.legend()
# Out:
# 0.09677646494005097
# 4.486128235811374e-05
# 7.671172498645487e-07
# 1.3629863915818732e-08
# 2.3177573862400097e-10

# %%
with open("fenton.txt","rt") as fenton:
    comp=fenton.read()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 with open("fenton.txt","rt") as fenton:
#       2     comp=fenton.read()
#
# File ~/.venv/jb/lib/python3.11/site-packages/IPython/core/interactiveshell.py:325, in _modified_open(file, *args, **kwargs)
#     318 if file in {0, 1, 2}:
#     319     raise ValueError(
#     320         f"IPython won't let you open fd={file} by default "
#     321         "as it is likely to crash IPython. If you know what you are doing, "
#     322         "you can use builtins' open."
#     323     )
# --> 325 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fenton.txt'

# %%
def data(line):
    if line=='':return False
    if line[0]=='#':return False
    return True
    
J,B,E=np.array([line.split('\t') for line in filter(data,comp.split('\n'))]).T

# %%
J.astype('int')

# %%
B=B.astype('float')

# %%
Etam,Bj,Ub,Q,R=nwfourier(20,0.1945,0.6484)

# %%
Bj-B

# %%
N=20
Xm=np.linspace(0,np.pi,N+1)
j=np.arange(1,N+1)
Xmj=Xm.reshape((N+1,1))@j.reshape((1,N))
Ej=(Etam[1:-1]@np.cos(Xmj)[1:-1])/10+Etam[0]*np.cos(Xmj)[0]/20+Etam[-1]*np.cos(Xmj)[-1]/20

# %%
E=E.astype(float)

# %%
Ej-E
